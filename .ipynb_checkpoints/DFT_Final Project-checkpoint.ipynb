# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mlt

# %% [markdown]
# # Import the Data

# %%
covid19_homeless_impact_WR2 = pd.read_csv(r'C:\Users\engma\Desktop\BST\DSO110-Final Group Project\DFT_Group\covid19_homeless_impact_WR2.csv')
covid19_homeless_impact_WR2.head()
# Out:
#         date         county  cumulative_population_cases  rooms  \
# 0  4.15.2020  San Francisco                          987   1012
# 1  4.16.2020  San Francisco                         1013   1271
# 2  4.17.2020  San Francisco                         1019   1271
# 3  4.18.2020  San Francisco                         1058   1271
# 4  4.19.2020  San Francisco                         1137   1273
#
#    rooms_occupied  trailers_requested  trailers_delivered  \
# 0             751                   0                   0
# 1             748                   0                   0
# 2             748                   0                   0
# 3             710                   0                   0
# 4             725                   0                   0
#
#    donated_trailers_delivered  cumulative_homeless_cases  \
# 0                           0                        119
# 1                           0                        120
# ...
